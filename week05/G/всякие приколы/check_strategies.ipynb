# %%
import pandas as pd
df = pd.read_csv("strategyA_.csv")
df
# Out:
#          N  time_r     time_n
# 0      100     218     2851.0
# 1      200     396     5688.0
# 2      300     526     8386.0
# 3      400     631    10682.0
# 4      500     799    13322.0
# ..     ...     ...        ...
# 494  49500   68773  1267600.0
# 495  49600   67806  1274840.0
# 496  49700   60121  1282740.0
# 497  49800   76068  1273390.0
# 498  49900   65416  1275370.0
#
# [499 rows x 3 columns]

# %%
from matplotlib import pyplot as plt
import numpy as np
N = np.array(df["N"])
tr = np.array(df["time_r"])
tn = np.array(df["time_n"])
fig, ax = plt.subplots(figsize=(6, 7))
ax.scatter(N, tr, s=1)
ax.set(xlabel='$N$',
       ylabel='search: t, ns')
# Out:
# [Text(0.5, 0, '$N$'), Text(0, 0.5, 'search: t, ns')]

# %%
from matplotlib import pyplot as plt
import numpy as np
N = np.array(df["N"])
tr = np.array(df["time_r"])
tn = np.array(df["time_n"])
fig, ax = plt.subplots(figsize=(6, 7))
ax.scatter(N, tn, s=1)
ax.set(xlabel='$N$',
       ylabel='search: t, ns')
# Out:
# [Text(0.5, 0, '$N$'), Text(0, 0.5, 'search: t, ns')]

# %%
from matplotlib import pyplot as plt
import numpy as np
N = np.array(df["N"])
tr = np.array(df["time_r"])
tn = np.array(df["time_n"])
fig, ax = plt.subplots(figsize=(6, 7))
ax.scatter(N, tr, s=1)
ax.scatter(N, tn, s=1)
ax.set(xlabel='$N$',
       ylabel='search: t, ns')
# Out:
# [Text(0.5, 0, '$N$'), Text(0, 0.5, 'search: t, ns')]

# %%
import pandas as pd
df2 = pd.read_csv("strategyC_.csv")
df2
# Out:
#          N  time_r     time_n
# 0      100     305     3911.0
# 1      200     483     7636.0
# 2      300     627    11389.0
# 3      400     804    17761.0
# 4      500    1130    18746.0
# ..     ...     ...        ...
# 494  49500   69623  1420320.0
# 495  49600   73978  1440060.0
# 496  49700   61159  1636300.0
# 497  49800   72851  1431780.0
# 498  49900   65953  1435370.0
#
# [499 rows x 3 columns]

# %%
from matplotlib import pyplot as plt
import numpy as np
N = np.array(df2["N"])
tr = np.array(df2["time_r"])
tn = np.array(df2["time_n"])
fig, ax = plt.subplots(figsize=(6, 7))
ax.scatter(N, tr, s=1)
ax.scatter(N, tn, s=1)
ax.set(xlabel='$N$',
       ylabel='search: t, ns')
# Out:
# [Text(0.5, 0, '$N$'), Text(0, 0.5, 'search: t, ns')]
