# %%
import pandas as pd
df = pd.read_csv("binsearch.csv")
df
# Out:
#          N  time
# 0      100    79
# 1      200    87
# 2      300    94
# 3      400    96
# 4      500    91
# ..     ...   ...
# 994  99500   147
# 995  99600   142
# 996  99700   146
# 997  99800   152
# 998  99900   157
#
# [999 rows x 2 columns]

# %%
from matplotlib import pyplot as plt
import numpy as np
N = np.array(df["N"])
search = np.array(df["time"])
fig, ax = plt.subplots(figsize=(6, 7))
ax.scatter(N, search, s=1)
ax.set(xlabel='$N$',
       ylabel='search: t, ns')
# Out:
# [Text(0.5, 0, '$N$'), Text(0, 0.5, 'search: t, ns')]

# %%
df2 = pd.read_csv("binsearch_extratime.csv")

# %%
N2 = np.array(df2["N"])
search2 = np.array(df2["time"])
fig, ax = plt.subplots(figsize=(6, 7))
ax.scatter(N2, search2, s=1)
ax.set(xlabel='$N$',
       ylabel='search: t, ns')
# Out:
# [Text(0.5, 0, '$N$'), Text(0, 0.5, 'search: t, ns')]
