# %%
import pandas as pd
df = pd.read_csv("search_times.csv")
df
# Out:
#          N  time_search  time_binsearch
# 0      100       0.2515           28.07
# 1    10100      23.6533           70.96
# 2    20100      47.4232           74.31
# 3    30100      65.7239           69.26
# 4    40100      88.3660           76.29
# 5    50100     108.2890           75.53
# 6    60100     135.7130           75.42
# 7    70100     152.2580           80.37
# 8    80100     175.3660           81.21
# 9    90100     196.4140           80.95
# 10  100100     217.0790           80.80
# 11  110100     239.4380           85.09
# 12  120100     262.6470           82.08
# 13  130100     280.5460           80.45
# 14  140100     304.0720           87.98
# 15  150100     323.9990           86.38
# 16  160100     346.5620           87.43
# 17  170100     368.0570           87.35
# 18  180100     391.6430           86.68
# 19  190100     413.8580           86.97
# 20  200100     434.0780           86.20
# 21  210100     457.0520           86.24
# ...

# %%
from matplotlib import pyplot as plt
import numpy as np
N = np.array(df["N"])
search = np.array(df["time_search"])
binsearch = np.array(df["time_binsearch"])
fig, ax = plt.subplots(figsize=(6, 7))
ax.scatter(N, search, s=3)
ax.set(xlabel='$N$',
       ylim=(-20, 1050), ylabel='search: t, mks')
# Out:
# [Text(0.5, 0, '$N$'), (-20.0, 1050.0), Text(0, 0.5, 'search: t, mks')]

# %%
import math
fig, ax = plt.subplots(figsize=(6, 7))

ax.scatter(N, binsearch, s=10)
ax.set(xlim=(-10000, 510000), xlabel='$N$',
       ylim=(20, 140), ylabel='binary search: t, mks')
x = np.arange(20, 500000, 1000)
y = [7.2*math.log(a) for a in x]
ax.plot(x, y, color='black', linestyle='--')
plt.show()

# %%
df2 = pd.read_csv("sum.csv")
df2
# Out:
#          N  time_simple  time_sorted
# 0      100          0.0          0.5
# 1     5100         29.7         16.6
# 2    10100        112.4         30.7
# 3    15100        258.7         47.9
# 4    20100        445.6         61.1
# 5    25100        688.6         76.3
# 6    30100        977.9         92.2
# 7    35100       1334.1        107.4
# 8    40100       1736.1        128.6
# 9    45100       2210.1        150.4
# 10   50100       2727.3        152.3
# 11   55100       3288.4        173.5
# 12   60100       3898.2        182.8
# 13   65100       4577.3        198.1
# 14   70100       5312.2        214.0
# 15   75100       6085.6        241.6
# 16   80100       7045.5        244.0
# 17   85100       7867.8        261.5
# 18   90100       8804.5        275.5
# 19   95100       9762.9        295.8
# 20  100100      10827.8        305.3
# 21  105100      11931.5        321.1
# 22  110100      13162.3        347.2
# 23  115100      14312.7        352.3
# ...

# %%
N2 = np.array(df2["N"])
simple = np.array(df2["time_simple"])
#simple[34] = 31724.9
sorted = np.array(df2["time_sorted"])
fig, ax = plt.subplots(figsize=(6, 7))
ax.scatter(N2, simple, s=3)
ax.set(xlabel='$N$',
       ylabel='non sorted array: t, ms')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 7))
ax.scatter(N2, sorted, s=3)
ax.set(xlabel='$N$',
        ylabel='sorted array: t, mks')
# Out:
# [Text(0.5, 0, '$N$'), Text(0, 0.5, 'sorted array: t, mks')]

# %%
df3 = pd.read_csv("strategy_A.csv")
df3
# Out:
#          N  time_ravnomerno  time_ne_ravnomerno
# 0      100           0.2147              0.3589
# 1    10100          14.8305             27.9134
# 2    20100          30.6810             48.9489
# 3    30100          43.0093             77.3817
# 4    40100          54.2998             97.2012
# 5    50100          68.9684            120.3120
# 6    60100          84.7410            159.9300
# 7    70100          97.4172            170.9530
# 8    80100         109.1140            191.4000
# 9    90100         122.0570            215.5510
# 10  100100         135.3570            239.2880
# 11  110100         148.9220            261.1320
# 12  120100         164.6610            283.0870
# 13  130100         177.0810            308.5840
# 14  140100         189.5300            332.1200
# 15  150100         203.7860            355.3910
# 16  160100         216.7130            379.1560
# 17  170100         231.2440            402.5440
# 18  180100         244.6320            424.2290
# ...

# %%
N3 = np.array(df3["N"])
ravn = np.array(df3["time_ravnomerno"])
neravn = np.array(df3["time_ne_ravnomerno"])
fig, ax = plt.subplots(figsize=(6, 7))
ax.scatter(N3, ravn, s=20, color='pink')
ax.scatter(N3, neravn, s=3, color='black')
ax.set(xlabel='$N$',
       ylabel='strategy A: t, mks')
plt.show()

# %%
df4 = pd.read_csv("strategy_B.csv")
df4
# Out:
#          N  time_ravnomerno  time_ne_ravnomerno
# 0      100           0.2114              0.3750
# 1    10100          14.6556             25.6246
# 2    20100          29.7373             48.8599
# 3    30100          41.3305             72.8645
# 4    40100          53.9205            100.1920
# 5    50100          69.0074            128.2530
# 6    60100          84.8095            144.7230
# 7    70100          97.8034            166.8560
# 8    80100         108.5400            192.1020
# 9    90100         122.0520            213.6440
# 10  100100         136.4000            239.7850
# 11  110100         148.8610            261.2750
# 12  120100         165.8730            301.6010
# 13  130100         188.4470            320.9960
# 14  140100         191.9450            333.8170
# 15  150100         203.4750            354.5860
# 16  160100         217.8910            377.8940
# 17  170100         242.7010            413.6720
# 18  180100         247.7620            424.1620
# ...

# %%
N4 = np.array(df4["N"])
ravn_B = np.array(df4["time_ravnomerno"])
neravn_B = np.array(df4["time_ne_ravnomerno"])
fig, ax = plt.subplots(figsize=(6, 7))
ax.scatter(N4, ravn_B, s=15, color='pink')
ax.scatter(N4, neravn_B, s=3, color='black')
ax.set(xlabel='$N$',
       ylabel='strategy B: t, mks')
plt.show()

# %%
df5 = pd.read_csv("strategy_C.csv")
df5
# Out:
#          N  time_ravnomerno  time_ne_ravnomerno
# 0      100           0.2210              0.3822
# 1    10100          14.8809             26.8905
# 2    20100          29.9122             49.9934
# 3    30100          42.6450             75.6080
# 4    40100          54.8495             96.7921
# 5    50100          74.1000            126.9680
# 6    60100          82.7454            146.6250
# 7    70100          94.6784            170.1450
# 8    80100         109.6750            195.0440
# 9    90100         123.1800            220.6020
# 10  100100         137.0610            244.2430
# 11  110100         150.7260            268.3720
# 12  120100         164.5470            291.1700
# 13  130100         178.8030            317.2330
# 14  140100         189.4430            342.8320
# 15  150100         204.0770            365.0580
# 16  160100         218.3850            389.4320
# 17  170100         230.7190            415.5770
# 18  180100         245.5320            438.1630
# ...

# %%
N5 = np.array(df4["N"])
ravn_C = np.array(df4["time_ravnomerno"])
neravn_C = np.array(df4["time_ne_ravnomerno"])
fig, ax = plt.subplots(figsize=(6, 7))
ax.scatter(N5, ravn_C, s=15, color='pink')
ax.scatter(N5, neravn_C, s=3, color='black')
ax.set(xlabel='$N$',
       ylabel='strategy B: t, mks')
plt.show()
